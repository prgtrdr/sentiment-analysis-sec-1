# %%
import edgar
import os, time
from pathlib2 import Path
import pandas as pd
import numpy as np
import requests
from tqdm import tqdm
import ProjectDirectory as directory
import re
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## generate df with all companies and URLs

# %%
project_dir = directory.get_project_dir()

# %%
os.chdir(os.path.join(project_dir, 'sec-filings-index'))

# %%
# filing_year = 2019   # uncomment to run, choose year to get all edgar filings from
# edgar.download_index(os.getcwd(), filing_year)

# %%
# Get list of all DFs 
table_list = []

for i in os.listdir():
    if i.endswith('.tsv'):
        table_list.append(pd.read_csv(i, sep='|', header=None, encoding='latin-1', parse_dates=[3], dtype={0: int}))

# %%
# append all dfs into a single df
df = pd.DataFrame(columns=[0,1,2,3,4,5])   # downloaded file has 6 columns

for i in range(len(table_list)):
        df = pd.concat([df, table_list[i]], ignore_index=True, axis=0)

df.columns= ['cik', 'company_name', 'filing_type', 'filing_date', 'url', 'url2']

# Fix up company names
df['company_name'] = [re.sub(r'/.*/|[\.\,]*', '', str(x)) for x in df['company_name']]

# %% [markdown]
# ## Check if dataframe correctly generated

# %%
count_list = []
for i in range(len(table_list)):
    count_list.append(len(table_list[i]))

if df.shape[0] == sum(count_list):
    print('df tallies with individual files. Total rows = {}'.format(df.shape[0]))
else:
    print('ERROR. df does not tally!!')
# Out:
# df tallies with individual files. Total rows = 7554694

# %% [markdown]
# ## Get CIK df

# %%
# cik_ticker_list.csv contains cik tickets of companies
# df_cik = pd.read_csv(os.path.join(project_dir, 'data', 'cik_ticker_list.csv'))
df_cik = pd.read_csv(os.path.join(project_dir, 'data', '1_analysts_202010151718.csv'))

# %%
def company_name_search(df, company_name_list):
    for company in company_name_list:
        df_company = df[df['Name'].str.contains(company, case=False)]
        print('*' * 50)
        print('SEARCH TERM: {}'.format(company))
        print('RESULTS:')
        for i in df_company['Name'].tolist():
            for j in df_company['CIK'].tolist():
                print(i, j)
        print('*' * 50)

# %%
def get_cik_from_company_name(df, company_name_list=None):
    cik_list = []
    if company_name_list is not None:
        for company in company_name_list:
            cik_series = df[df['Name'].str.contains(company, case=False)]['CIK']
            cik_list.append(cik_series.values[0])
    else:
        cik_list = df['CIK'].tolist()        
    return cik_list

# %%
def get_company_name_from_cik(df, cik_list):
    company_list = []
    for cik in cik_list:
        company_series = df[df['CIK'] == cik]
        company_list.append(company_series.values[0])
    return company_list

# %%
companies_list = ['apple inc', 'tesla', 'netflix', 
                  'amazon com inc', 'microsoft', 'facebook']

# %%
company_name_search(df_cik, companies_list)
# Out:
# **************************************************
# SEARCH TERM: apple inc
# RESULTS:
# **************************************************
# **************************************************
# SEARCH TERM: tesla
# RESULTS:
# **************************************************
# **************************************************
# SEARCH TERM: netflix
# RESULTS:
# **************************************************
# **************************************************
# SEARCH TERM: amazon com inc
# RESULTS:
# **************************************************
# **************************************************
# SEARCH TERM: microsoft
# RESULTS:
# **************************************************
# **************************************************
# SEARCH TERM: facebook
# RESULTS:
# **************************************************

# %%
# cik_list = get_cik_from_company_name(df_cik, companies_list)
cik_list = get_cik_from_company_name(df_cik)

# %% [markdown]
# ## download data

# %%
def download_filings(cik_num_list, from_date='2018-01-01'):
    """Function to filter the appropriate filings and download them in the folder"""
    
    project_dir = directory.get_project_dir()
    
    # filter df with company CIK,filing type (10-K and 10-Q) and date  
    df_filtered = df [(df['cik'].isin(cik_num_list)) & 
                      ((df['filing_type']=='10-K') | (df['filing_type'] == '10-Q')) & 
                      (df['filing_date'] > from_date)]
    
    company_names = df_filtered['company_name'].unique().tolist()
    
    # check if folders for each company already exists    
    sec_filings_dir = os.path.join(project_dir, 'sec-filings-downloaded')  # dir to download SEC filingsa
    os.chdir(sec_filings_dir)

    for company in company_names:
        company_dir = os.path.join(sec_filings_dir, company)

        if not os.path.exists(company_dir):
            os.makedirs(company_dir)
            print('\n created dir: {}'.format(company))
        else:
            print('\n{} directory exists'.format(company))
            
        os.chdir(company_dir)
        
        # create company specific df to iterate over    
        df_filtered_co = df_filtered[df_filtered['company_name'] == company]  # get df with the company only
        df_filtered_co['filing_date'] = df_filtered_co['filing_date'].astype(str)   # convert to 'object' to name file
        
        for i in range(len(df_filtered_co)):
            url_prefix = 'https://www.sec.gov/Archives/'
            row = df_filtered_co.iloc[i,:]
            url = url_prefix + row['url']
            response = requests.get(url, stream=True, timeout=30)
            
            filing_name = row['filing_date'] + str('_') + row['filing_type']
            if os.path.isfile(filing_name):
                print('{} file already exists'.format(filing_name))
            else:
                print('Downloading: {}'.format(filing_name))
                with open('{}'.format(filing_name), 'wb') as handle:
                    for data in tqdm(response.iter_content()):
                        handle.write(data)

# %% [markdown]
# ### ↓ Automated download of filings. If the filing exists in the directory, the download will skip and move on the the next filing

# %%
download_filings(cik_list)
# Out:
#  already exists
# 2020-08-10_10-Q file already exists
#
# AG Mortgage Investment Trust Inc directory exists
# 2018-02-28_10-K file already exists
# 2018-05-03_10-Q file already exists
# 2018-08-07_10-Q file already exists
# 2018-11-09_10-Q file already exists
# 2019-02-27_10-K file already exists
# 2019-05-03_10-Q file already exists
# 2019-08-06_10-Q file already exists
# 2019-11-05_10-Q file already exists
# 2020-02-28_10-K file already exists
# 2020-06-12_10-Q file already exists
# 2020-08-10_10-Q file already exists
#
# SunCoke Energy Inc directory exists
# 2018-02-15_10-K file already exists
# 2018-04-26_10-Q file already exists
# 2018-07-26_10-Q file already exists
# 2018-10-25_10-Q file already exists
# 2019-02-15_10-K file already exists
# 2019-04-24_10-Q file already exists
# 2019-07-30_10-Q file already exists
# 2019-11-05_10-Q file already exists
# 2020-02-20_10-K file already exists
# 2020-05-08_10-Q file already exists
# 2020-08-03_10-Q file already exists
#
# Manning & Napier Inc directory exists
# 2018-03-16_10-K file already exists
# 2018-05-10_10-Q file already exists
# 2018-08-09_10-Q file already exists
# 2018-11-08_10-Q file already exists
# 2019-05-14_10-Q file already exists
# 2019-08-13_10-Q file already exists
# 2019-11-14_10-Q file already exists
# 2020-03-13_10-K file already exists
# 2020-05-15_10-Q file already exists
# 2020-08-14_10-Q file already exists
#
# ERA GROUP INC directory exists
# 2018-03-09_10-K file already exists
# 2018-05-01_10-Q file already exists
# 2018-08-07_10-Q file already exists
# 2018-11-06_10-Q file already exists
# 2019-05-07_10-Q file already exists
# 2019-07-30_10-Q file already exists
# 2019-11-05_10-Q file already exists
# 2020-03-06_10-K file already exists
# 2020-05-05_10-Q file already exists
#
# Sprague Resources LP directory exists
# 2018-03-14_10-K file already exists
# 2018-05-08_10-Q file already exists
# 2018-08-08_10-Q file already exists
# 2018-11-07_10-Q file already exists
# 2019-05-08_10-Q file already exists
# 2019-08-07_10-Q file already exists
# 2019-11-07_10-Q file already exists
# 2020-03-05_10-K file already exists
# 2020-05-07_10-Q file already exists
# 2020-08-06_10-Q file already exists
#
# Natural Grocers by Vitamin Cottage Inc directory exists
# 2018-02-01_10-Q file already exists
# 2018-05-03_10-Q file already exists
# 2018-08-02_10-Q file already exists
# 2018-12-06_10-K file already exists
# 2019-02-07_10-Q file already exists
# 2019-05-02_10-Q file already exists
# 2019-08-01_10-Q file already exists
# 2019-12-05_10-K file already exists
# 2020-02-06_10-Q file already exists
# 2020-05-07_10-Q file already exists
# 2020-08-06_10-Q file already exists
#
# Ellington Residential Mortgage REIT directory exists
# 2018-03-14_10-K file already exists
# 2018-05-04_10-Q file already exists
# 2018-08-06_10-Q file already exists
# 2018-11-07_10-Q file already exists
# 2019-05-09_10-Q file already exists
# 2019-08-08_10-Q file already exists
# 2019-11-06_10-Q file already exists
# 2020-03-12_10-K file already exists
# 2020-05-11_10-Q file already exists
# 2020-08-07_10-Q file already exists
#
# Third Point Reinsurance Ltd directory exists
# 2018-03-01_10-K file already exists
# 2018-05-10_10-Q file already exists
# 2018-07-31_10-Q file already exists
# 2018-11-06_10-Q file already exists
# 2019-02-28_10-K file already exists
# 2019-05-09_10-Q file already exists
# 2019-08-07_10-Q file already exists
# 2019-11-05_10-Q file already exists
# 2020-02-28_10-K file already exists
# 2020-05-07_10-Q file already exists
# 2020-08-10_10-Q file already exists
#
# Cypress Energy Partners LP directory exists
# 2018-03-23_10-K file already exists
# 2018-05-11_10-Q file already exists
# 2018-08-14_10-Q file already exists
# 2018-11-13_10-Q file already exists
# 2019-05-13_10-Q file already exists
# 2019-08-14_10-Q file already exists
# 2019-11-12_10-Q file already exists
#
# DELUXE CORP directory exists
# 2018-02-23_10-K file already exists
# 2018-05-03_10-Q file already exists
# 2018-07-27_10-Q file already exists
# 2018-10-26_10-Q file already exists
# 2019-02-26_10-K file already exists
# 2019-05-03_10-Q file already exists
# 2019-07-26_10-Q file already exists
# 2019-10-25_10-Q file already exists
# 2020-02-21_10-K file already exists
# 2020-05-08_10-Q file already exists
# 2020-07-31_10-Q file already exists
#
# PANHANDLE OIL & GAS INC directory exists
# 2018-02-08_10-Q file already exists
# 2018-05-07_10-Q file already exists
# 2018-08-06_10-Q file already exists
# 2018-12-11_10-K file already exists
# 2019-02-07_10-Q file already exists
# 2019-05-09_10-Q file already exists
# 2019-08-08_10-Q file already exists
# 2019-12-13_10-K file already exists
# 2020-02-05_10-Q file already exists
# 2020-05-07_10-Q file already exists
# 2020-08-13_10-Q file already exists
#
# ENNIS INC directory exists
# 2018-01-05_10-Q file already exists
# 2018-05-11_10-K file already exists
# 2018-07-06_10-Q file already exists
# 2018-10-05_10-Q file already exists
# 2019-01-04_10-Q file already exists
# 2019-05-06_10-K file already exists
# 2019-07-03_10-Q file already exists
# 2019-10-02_10-Q file already exists
# 2020-01-03_10-Q file already exists
# 2020-05-04_10-K file already exists
# 2020-07-02_10-Q file already exists
# 2020-10-07_10-Q file already exists
#
# HARTE HANKS INC directory exists
# 2018-03-15_10-K file already exists
# 2018-05-11_10-Q file already exists
# 2018-08-09_10-Q file already exists
# 2018-11-08_10-Q file already exists
# 2019-05-09_10-Q file already exists
# 2019-08-09_10-Q file already exists
# 2019-11-12_10-Q file already exists
# 2020-03-19_10-K file already exists
# 2020-05-14_10-Q file already exists
# 2020-08-14_10-Q file already exists
#
# VALHI INC  directory exists
# 4923it [00:00, 48834.88it/s]Downloading: 2018-03-15_10-K
# 1258000it [00:23, 54012.39it/s]
# 4591it [00:00, 45576.88it/s]Downloading: 2018-05-09_10-Q
# 559851it [00:10, 55381.11it/s]
# 4337it [00:00, 43042.88it/s]Downloading: 2018-08-08_10-Q
# 638377it [00:11, 54659.33it/s]
# 8501it [00:00, 42684.14it/s]Downloading: 2018-11-08_10-Q
# 655450it [00:12, 54384.42it/s]
# 8734it [00:00, 44126.40it/s]Downloading: 2019-05-09_10-Q
# 491752it [00:09, 54517.63it/s]
# 4247it [00:00, 42151.46it/s]Downloading: 2019-08-08_10-Q
# 531362it [00:09, 54454.16it/s]
# 8259it [00:00, 41368.44it/s]Downloading: 2019-11-08_10-Q
# 587266it [00:10, 55201.95it/s]
# 9130it [00:00, 45970.12it/s]Downloading: 2020-03-12_10-K
# 1281604it [00:23, 54026.04it/s]
# 8689it [00:00, 43673.92it/s]Downloading: 2020-05-07_10-Q
# 456942it [00:09, 45792.54it/s]
# 3801it [00:00, 37918.46it/s]Downloading: 2020-08-06_10-Q
# 606080it [00:14, 40899.19it/s]
#
# VECTOR GROUP LTD directory exists
# 2018-03-01_10-K file already exists
# 2018-05-10_10-Q file already exists
# 2018-08-07_10-Q file already exists
# 2018-11-09_10-Q file already exists
# 2019-03-01_10-K file already exists
# 2019-05-10_10-Q file already exists
# 2019-08-09_10-Q file already exists
# 2019-11-07_10-Q file already exists
# 2020-03-02_10-K file already exists
# 2020-05-11_10-Q file already exists
# 2020-08-07_10-Q file already exists
#
# AMERICAN VANGUARD CORP directory exists
# 2018-03-14_10-K file already exists
# 2018-05-08_10-Q file already exists
# 2018-08-06_10-Q file already exists
# 2018-11-06_10-Q file already exists
# 2019-05-08_10-Q file already exists
# 2019-08-07_10-Q file already exists
# 2019-11-06_10-Q file already exists
# 2020-03-10_10-K file already exists
# 2020-05-11_10-Q file already exists
# 2020-08-07_10-Q file already exists
#
# AMPCO PITTSBURGH CORP directory exists
# 2018-03-16_10-K file already exists
# 2018-05-10_10-Q file already exists
# 2018-08-09_10-Q file already exists
# 2018-11-09_10-Q file already exists
# 2019-05-10_10-Q file already exists
# 2019-08-08_10-Q file already exists
# 2019-11-08_10-Q file already exists
# 2020-03-16_10-K file already exists
# 2020-05-11_10-Q file already exists
# 2020-08-10_10-Q file already exists
#
# MERCURY GENERAL CORP directory exists
# 2018-02-08_10-K file already exists
# 2018-05-01_10-Q file already exists
# 2018-07-31_10-Q file already exists
# 2018-10-30_10-Q file already exists
# 2019-02-13_10-K file already exists
# 2019-04-30_10-Q file already exists
# 2019-07-30_10-Q file already exists
# 2019-10-29_10-Q file already exists
# 2020-02-12_10-K file already exists
# 2020-05-05_10-Q file already exists
# 2020-08-04_10-Q file already exists
#
# ONE LIBERTY PROPERTIES INC directory exists
# 2018-03-14_10-K file already exists
# 2018-05-07_10-Q file already exists
# 2018-08-06_10-Q file already exists
# 2018-11-08_10-Q file already exists
# 2019-05-09_10-Q file already exists
# 2019-08-07_10-Q file already exists
# 2019-11-08_10-Q file already exists
# 2020-03-16_10-K file already exists
# 2020-05-08_10-Q file already exists
# 2020-08-07_10-Q file already exists
#
# NL INDUSTRIES INC directory exists
# 2018-03-12_10-K file already exists
# 2018-05-08_10-Q file already exists
# 2018-08-07_10-Q file already exists
# 2018-11-07_10-Q file already exists
# 2019-05-09_10-Q file already exists
# 2019-08-07_10-Q file already exists
# 2019-11-07_10-Q file already exists
# 2020-03-11_10-K file already exists
# 2020-05-06_10-Q file already exists
# 2020-08-05_10-Q file already exists
#
# MOVADO GROUP INC directory exists
# 2018-03-29_10-K file already exists
# 2018-05-30_10-Q file already exists
# 2018-08-29_10-Q file already exists
# 2018-12-04_10-Q file already exists
# 2019-05-30_10-Q file already exists
# 2019-08-28_10-Q file already exists
# 2019-11-26_10-Q file already exists
# 2020-03-26_10-K file already exists
# 2020-06-09_10-Q file already exists
# 2020-08-27_10-Q file already exists
#
# REX AMERICAN RESOURCES Corp directory exists
# 2018-03-29_10-K file already exists
# 2018-06-04_10-Q file already exists
# 2018-09-05_10-Q file already exists
# 2018-12-03_10-Q file already exists
# 2019-06-04_10-Q file already exists
# 2019-09-04_10-Q file already exists
# 2019-12-05_10-Q file already exists
# 2020-04-01_10-K file already exists
# 2020-06-04_10-Q file already exists
# 2020-09-02_10-Q file already exists
#
# UNISYS CORP directory exists
# 2018-03-12_10-K file already exists
# 2018-05-02_10-Q file already exists
# 2018-08-01_10-Q file already exists
# 2018-11-09_10-Q file already exists
# 2019-05-03_10-Q file already exists
# 2019-07-30_10-Q file already exists
# 2019-10-30_10-Q file already exists
# 2020-02-28_10-K file already exists
# 2020-04-28_10-Q file already exists
# 2020-08-04_10-Q file already exists
#
# PENNSYLVANIA REAL ESTATE INVESTMENT TRUST directory exists
# 2018-02-16_10-K file already exists
# 2018-05-04_10-Q file already exists
# 2018-08-03_10-Q file already exists
# 2018-11-01_10-Q file already exists
# 2019-02-25_10-K file already exists
# 2019-05-07_10-Q file already exists
# 2019-08-02_10-Q file already exists
# 2019-11-04_10-Q file already exists
# 2020-03-16_10-K file already exists
# 2020-05-21_10-Q file already exists
# 2020-08-11_10-Q file already exists
#
# WHITE MOUNTAINS INSURANCE GROUP LTD directory exists
# 2018-02-28_10-K file already exists
# 2018-05-02_10-Q file already exists
# 2018-08-07_10-Q file already exists
# 2018-11-05_10-Q file already exists
# 2019-02-27_10-K file already exists
# 2019-05-06_10-Q file already exists
# 2019-08-06_10-Q file already exists
# 2019-11-06_10-Q file already exists
# 2020-03-02_10-K file already exists
# 2020-05-08_10-Q file already exists
# 2020-08-07_10-Q file already exists
#
# BRANDYWINE REALTY TRUST directory exists
# 2018-02-23_10-K file already exists
# 2018-04-26_10-Q file already exists
# 2018-07-27_10-Q file already exists
# 2018-10-23_10-Q file already exists
# 2019-02-22_10-K file already exists
# 2019-05-03_10-Q file already exists
# 2019-08-06_10-Q file already exists
# 2019-10-24_10-Q file already exists
# 2020-03-02_10-K file already exists
# 2020-04-28_10-Q file already exists
# 2020-07-28_10-Q file already exists
#
# UNIT CORP directory exists
# 2018-02-27_10-K file already exists
# 2018-05-03_10-Q file already exists
# 2018-08-09_10-Q file already exists
# 2018-11-06_10-Q file already exists
# 2019-02-26_10-K file already exists
# 2019-05-02_10-Q file already exists
# 2019-08-06_10-Q file already exists
# 2019-11-08_10-Q file already exists
# 2020-03-16_10-K file already exists
# 2020-06-25_10-Q file already exists
#
# LINDSAY CORP directory exists
# 2018-03-29_10-Q file already exists
# 2018-06-29_10-Q file already exists
# 2018-10-24_10-K file already exists
# 2019-01-09_10-Q file already exists
# 2019-04-09_10-Q file already exists
# 2019-07-09_10-Q file already exists
# 2019-10-31_10-K file already exists
# 2020-01-09_10-Q file already exists
# 2020-04-07_10-Q file already exists
# 2020-07-02_10-Q file already exists
#
# FEDERAL AGRICULTURAL MORTGAGE CORP directory exists
# 2018-03-08_10-K file already exists
# 2018-05-10_10-Q file already exists
# 2018-08-09_10-Q file already exists
# 2018-11-08_10-Q file already exists
# 2019-02-21_10-K file already exists
# 2019-05-02_10-Q file already exists
# 2019-08-01_10-Q file already exists
# 2019-11-06_10-Q file already exists
# 2020-02-25_10-K file already exists
# 2020-05-11_10-Q file already exists
# 2020-08-10_10-Q file already exists
#
# PS BUSINESS PARKS INC/CA directory exists
# 2018-02-26_10-K file already exists
# 2018-05-03_10-Q file already exists
# 2018-07-30_10-Q file already exists
# 2018-10-29_10-Q file already exists
# 2019-02-26_10-K file already exists
# 2019-05-01_10-Q file already exists
# 2019-07-26_10-Q file already exists
# 2019-10-23_10-Q file already exists
# 2020-02-19_10-K file already exists
# 2020-04-30_10-Q file already exists
# 2020-08-05_10-Q file already exists
#
# OCWEN FINANCIAL CORP directory exists
# 2018-02-28_10-K file already exists
# 2018-05-02_10-Q file already exists
# 2018-07-26_10-Q file already exists
# 2018-11-06_10-Q file already exists
# 2019-02-27_10-K file already exists
# 2019-05-07_10-Q file already exists
# 2019-08-06_10-Q file already exists
# 2019-11-05_10-Q file already exists
# 2020-02-26_10-K file already exists
# 2020-05-08_10-Q file already exists
# 2020-08-04_10-Q file already exists
#
# REVLON INC  directory exists
# 2018-03-15_10-K file already exists
# 2018-05-10_10-Q file already exists
# 2018-08-09_10-Q file already exists
# 2018-11-09_10-Q file already exists
# 2019-05-09_10-Q file already exists
# 2019-08-08_10-Q file already exists
# 2019-11-08_10-Q file already exists
# 2020-03-12_10-K file already exists
# 2020-05-11_10-Q file already exists
# 2020-08-06_10-Q file already exists
#
# UNIVERSAL INSURANCE HOLDINGS INC directory exists
# 2018-02-23_10-K file already exists
# 2018-04-27_10-Q file already exists
# 2018-07-27_10-Q file already exists
# 2018-10-31_10-Q file already exists
# 2019-03-01_10-K file already exists
# 2019-04-26_10-Q file already exists
# 2019-08-02_10-Q file already exists
# 2019-11-04_10-Q file already exists
# 2020-03-02_10-K file already exists
# 2020-05-01_10-Q file already exists
# 2020-07-31_10-Q file already exists
#
# CHESAPEAKE ENERGY CORP directory exists
# 2018-02-22_10-K file already exists
# 2018-05-02_10-Q file already exists
# 2018-08-01_10-Q file already exists
# 2018-10-30_10-Q file already exists
# 2019-02-27_10-K file already exists
# 2019-05-09_10-Q file already exists
# 2019-08-06_10-Q file already exists
# 2019-11-05_10-Q file already exists
# 2020-02-27_10-K file already exists
# 2020-05-11_10-Q file already exists
# 2020-08-10_10-Q file already exists
#
# EQUITY LIFESTYLE PROPERTIES INC directory exists
# 2018-02-28_10-K file already exists
# 2018-05-02_10-Q file already exists
# 2018-07-26_10-Q file already exists
# 2018-10-25_10-Q file already exists
# 2019-02-26_10-K file already exists
# 2019-04-30_10-Q file already exists
# 2019-07-30_10-Q file already exists
# 2019-10-30_10-Q file already exists
# 2020-02-24_10-K file already exists
# 2020-04-28_10-Q file already exists
# 2020-07-28_10-Q file already exists
#
# ALAMO GROUP INC directory exists
# 2018-03-01_10-K file already exists
# 2018-05-03_10-Q file already exists
# 2018-08-01_10-Q file already exists
# 2018-10-31_10-Q file already exists
# 2019-03-01_10-K file already exists
# 2019-05-01_10-Q file already exists
# 2019-07-31_10-Q file already exists
# 2019-10-31_10-Q file already exists
# 2020-02-28_10-K file already exists
# 2020-05-07_10-Q file already exists
# 2020-07-30_10-Q file already exists
#
# VORNADO REALTY TRUST directory exists
# 2018-02-12_10-K file already exists
# 2018-04-30_10-Q file already exists
# 2018-07-30_10-Q file already exists
# 2018-10-29_10-Q file already exists
# 2019-02-11_10-K file already exists
# 2019-04-29_10-Q file already exists
# 2019-07-29_10-Q file already exists
# 2019-10-28_10-Q file already exists
# 2020-02-18_10-K file already exists
# 2020-05-04_10-Q file already exists
# 2020-08-03_10-Q file already exists
#
# CBL & ASSOCIATES PROPERTIES INC directory exists
# 2018-03-01_10-K file already exists
# 2018-05-10_10-Q file already exists
# 2018-08-09_10-Q file already exists
# 2018-11-09_10-Q file already exists
# 2019-03-01_10-K file already exists
# 2019-05-10_10-Q file already exists
# 2019-08-09_10-Q file already exists
# 2019-11-12_10-Q file already exists
# 2020-03-09_10-K file already exists
# 2020-06-05_10-Q file already exists
# 2020-08-17_10-Q file already exists
#
# BEAZER HOMES USA INC directory exists
# 2018-02-06_10-Q file already exists
# 2018-05-02_10-Q file already exists
# 2018-07-26_10-Q file already exists
# 2018-11-13_10-K file already exists
# 2019-02-04_10-Q file already exists
# 2019-05-02_10-Q file already exists
# 2019-08-01_10-Q file already exists
# 2019-11-13_10-K file already exists
# 2020-01-30_10-Q file already exists
# 2020-04-30_10-Q file already exists
# 2020-07-30_10-Q file already exists
#
# AK STEEL HOLDING CORP directory exists
# 2018-02-15_10-K file already exists
# 2018-04-30_10-Q file already exists
# 2018-07-30_10-Q file already exists
# 2018-10-26_10-Q file already exists
# 2019-02-15_10-K file already exists
# 2019-04-29_10-Q file already exists
# 2019-07-29_10-Q file already exists
# 2019-10-30_10-Q file already exists
# 2020-02-20_10-K file already exists
#
# FLOTEK INDUSTRIES INC directory exists
# 2018-03-08_10-K file already exists
# 2018-05-09_10-Q file already exists
# 2018-08-08_10-Q file already exists
# 2018-11-06_10-Q file already exists
# 2019-05-09_10-Q file already exists
# 2019-08-08_10-Q file already exists
# 2019-11-12_10-Q file already exists
# 2020-03-06_10-K file already exists
# 2020-06-12_10-Q file already exists
# 2020-08-17_10-Q file already exists
#
# SUPERIOR INDUSTRIES INTERNATIONAL INC directory exists
# 2018-03-15_10-K file already exists
# 2018-05-09_10-Q file already exists
# 2018-08-08_10-Q file already exists
# 2018-11-09_10-Q file already exists
# 2019-05-09_10-Q file already exists
# 2019-08-08_10-Q file already exists
# 2019-11-04_10-Q file already exists
# 2020-02-28_10-K file already exists
# 2020-05-08_10-Q file already exists
# 2020-08-05_10-Q file already exists
#
# TEXAS PACIFIC LAND TRUST directory exists
# 2018-02-28_10-K file already exists
# 2018-05-07_10-Q file already exists
# 2018-08-07_10-Q file already exists
# 2018-11-07_10-Q file already exists
# 2019-02-28_10-K file already exists
# 2019-05-07_10-Q file already exists
# 2019-08-07_10-Q file already exists
# 2019-11-07_10-Q file already exists
# 2020-02-27_10-K file already exists
# 2020-05-07_10-Q file already exists
# 2020-08-06_10-Q file already exists
#
# Red Lion Hotels CORP directory exists
# 2018-04-02_10-K file already exists
# 2018-05-09_10-Q file already exists
# 2018-08-09_10-Q file already exists
# 2018-11-06_10-Q file already exists
# 2019-05-09_10-Q file already exists
# 2019-08-06_10-Q file already exists
# 2019-11-12_10-Q file already exists
# 2020-02-27_10-K file already exists
# 2020-05-08_10-Q file already exists
# 2020-08-06_10-Q file already exists
#
# VINCE HOLDING CORP directory exists
# 2018-04-25_10-K file already exists
# 2018-06-14_10-Q file already exists
# 2018-09-13_10-Q file already exists
# 2018-12-13_10-Q file already exists
# 2019-04-12_10-K file already exists
# 2019-06-13_10-Q file already exists
# 2019-09-12_10-Q file already exists
# 2019-12-12_10-Q file already exists
# 2020-06-11_10-K file already exists
# 2020-07-31_10-Q file already exists
# 2020-09-15_10-Q file already exists
#
# BUCKLE INC directory exists
# 2018-04-04_10-K file already exists
# 2018-06-14_10-Q file already exists
# 2018-09-13_10-Q file already exists
# 2018-12-13_10-Q file already exists
# 2019-04-03_10-K file already exists
# 2019-06-13_10-Q file already exists
# 2019-09-12_10-Q file already exists
# 2019-12-12_10-Q file already exists
# 2020-04-01_10-K file already exists
# 2020-06-11_10-Q file already exists
# 2020-09-10_10-Q file already exists
#
# Cypress Environmental Partners LP directory exists
# 2020-03-16_10-K file already exists
# 2020-05-11_10-Q file already exists
# 2020-08-13_10-Q file already exists
#
# Bristow Group Inc directory exists
# 2020-08-07_10-Q file already exists
